# %%
#PROGRAM TO CREATE AN ALGORITHM TO REPRESENT THE DATA IN A TABLE FORM

girlsname = ['Evelyn' , 'Jessica', 'Somto', 'Edith ', 'liza', 'Madonna', 'waje', 'Tola','Aisha','Latifa']
girlsage = [17,16,17,18,16,18,17,20,19,17]
girlsheight =[5.5,6.0,5.4,5.9,5.6,5.5,6.1,6.0,5.7,5.5]
girlsscore =[80,85,70,60,76,66,87,95,50,49]

boysname =['Chinedu', 'Liam', 'Wale', 'Gbenga', 'Abiola', 'Kola',' Kunle', 'George', 'Thomas' , 'Wesley']
boysage = [19, 16, 18, 17, 20, 19, 16, 18, 17, 19]
boysheight = [5.7, 5.9, 5.8, 6.1, 5.9, 5.5, 61, 5.4, 5.8, 5.7]
boyscore = [74, 87, 75, 68, 66, 78, 87, 98, 54, 60]

print("Girls Table")
print (" NAME  | AGE|HEIGHT|SCORE|")
print ( girlsname[0] ,'|',girlsage[0],'|', girlsheight [0],'|', girlsscore[0])
print ( girlsname[1] ,'|',girlsage[1],'|', girlsheight [1],'|', girlsscore[1])
print ( girlsname[2] ,'|',girlsage[2],'|', girlsheight [2],'|', girlsscore[2])
print ( girlsname[3] ,'|',girlsage[3],'|', girlsheight [3],'|', girlsscore[3])
print ( girlsname[4] ,'|',girlsage[4],'|', girlsheight [4],'|', girlsscore[4])
print ( girlsname[5] ,'|',girlsage[5],'|', girlsheight [5],'|', girlsscore[5])
print ( girlsname[6] ,'|',girlsage[6],'|', girlsheight [6],'|', girlsscore[6])
print ( girlsname[7] ,'|',girlsage[7],'|', girlsheight [7],'|', girlsscore[7])
print ( girlsname[8] ,'|',girlsage[8],'|', girlsheight [8],'|', girlsscore[8])
print ( girlsname[9] ,'|',girlsage[9],'|', girlsheight [9],'|', girlsscore[9])





print("Boys Table")
print (" NAME  | AGE|HEIGHT|SCORE|")
print ( boysname[0] ,'|',boysage[0],'|', boysheight [0],'|', boyscore[0])
print ( boysname[1] ,'|',boysage[1],'|', boysheight [1],'|', boyscore[1])
print ( boysname[2] ,'|',boysage[2],'|', boysheight [2],'|', boyscore[2])
print ( boysname[3] ,'|',boysage[3],'|', boysheight [3],'|', boyscore[3])
print ( boysname[4] ,'|',boysage[4],'|', boysheight [4],'|', boyscore[4])
print ( boysname[5] ,'|',boysage[5],'|', boysheight [5],'|', boyscore[5])
print ( boysname[6] ,'|',boysage[6],'|', boysheight [6],'|', boyscore[6])
print ( boysname[7] ,'|',boysage[7],'|', boysheight [7],'|', boyscore[7])
print ( boysname[8] ,'|',boysage[8],'|', boysheight [8],'|', boyscore[8])
print ( boysname[9] ,'|',boysage[9],'|', boysheight [9],'|', boyscore[9])
# Out:
# Girls Table
#  NAME  | AGE|HEIGHT|SCORE|
# Evelyn | 17 | 5.5 | 80
# Jessica | 16 | 6.0 | 85
# Somto | 17 | 5.4 | 70
# Edith  | 18 | 5.9 | 60
# liza | 16 | 5.6 | 76
# Madonna | 18 | 5.5 | 66
# waje | 17 | 6.1 | 87
# Tola | 20 | 6.0 | 95
# Aisha | 19 | 5.7 | 50
# Latifa | 17 | 5.5 | 49
# Boys Table
#  NAME  | AGE|HEIGHT|SCORE|
# Chinedu | 19 | 5.7 | 74
# Liam | 16 | 5.9 | 87
# Wale | 18 | 5.8 | 75
# Gbenga | 17 | 6.1 | 68
# Abiola | 20 | 5.9 | 66
# Kola | 19 | 5.5 | 78
#  Kunle | 16 | 61 | 87
# George | 18 | 5.4 | 98
# Thomas | 17 | 5.8 | 54
# Wesley | 19 | 5.7 | 60
