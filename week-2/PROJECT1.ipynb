# %%
# project 1 part 3 

INPUT Name1
INPUT Age1

INPUT Name2
INPUT Age2

Temp = Age1
Age1 = Age2
Age2 = Temp

DISPLAY Name1, "new age =", Age1
DISPLAY Name2, "new age =", Age2

END

# %% [markdown]
# ![Screenshot 2026-03-13 213115.png](attachment:beba4bff-e905-4887-901f-c07f1223e2d3.png)#

# %%
# project 1 part 1 
BEGIN

SET Total = 0

REPEAT

    DISPLAY "Enter item price"

    INPUT Price

    Total = Total + Price

    DISPLAY "Is that all items? (YES/NO)"

    INPUT Answer

UNTIL Answer = "YES"

DISPLAY "Total amount =", Total

DISPLAY "Enter amount paid"

INPUT Payment

Change = Payment - Total

DISPLAY "Change =", Change

END
