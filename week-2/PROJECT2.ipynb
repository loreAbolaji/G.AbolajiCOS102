# %%
#program to calculate equation 
import numpy as np
print ("select the number of which calculation you would like to proceed with ")
print("1. quadratic equation")
print("2. cubic equation")
print("3. quartic equation")

choice = int(input("input a number"))
if choice ==1:
    a = float(input("Enter a: "))
    b = float(input("Enter b: "))
    c = float(input("Enter c: "))

    QE = (b**2) - (4*a*c)

    if QE > 0:
        r1 = (-b + D**0.5) / (2*a)
        r2 = (-b - D**0.5) / (2*a)
        print("Roots:", r1, r2)
    elif QE == 0:
        r = -b/(2*a)
        print("Root:", r)
    else:
        print("Complex roots")

elif choice == 2:
    A = float(input("Enter A: "))
    B = float(input("Enter B: "))
    C = float(input("Enter C: "))
    D = float(input("Enter D: "))

    cube = [A,B,C,D]
    roots = np.roots(cube)
    print("Roots:", roots)

elif choice == 3:
    A = float(input("Enter A: "))
    B = float(input("Enter B: "))
    C = float(input("Enter C: "))
    D = float(input("Enter D: "))
    E = float(input("Enter E: "))

    quad = [A,B,C,D,E]
    roots = np.roots(quad)
    print("Roots:", roots)
# Out:
# select the number of which calculation you would like to proceed with
# 1. quadratic equation
# 2. cubic equation
# 3. quartic equation
# input a number 1
# Enter a:  2
# Enter b:  2
# Enter c:  3
# Complex roots
