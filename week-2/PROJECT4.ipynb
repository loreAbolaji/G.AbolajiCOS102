# %%
print("Hello Good Day Welcome to IZIFIN Technology ")
print("Enter your Name")
Name = input()
print("Enter your years of Experience ")
Years = int(input())
print("Enter your Age")
Age = int(input())

if Years >=25 and Age >=55:
    print("Your Annuanl Tax Revenue ATR ", Name ," is #5600000")     
elif Years >=20 and Age >=45:
    print("Your Annuanl Tax Revenue ATR ", Name ," is #4480000") 
elif Years >=10 and Age >=35:
    print("Your Annuanl Tax Revenue ATR ", Name ," is #1500000") 
elif Years <10 and Age <35:
    print("Your Annuanl Tax Revenue ATR ", Name ," is #550000")  
elif Years > Age:
    print("Error: Years of experience cannot be greater than your age.")
# Out:
# Hello Good Day Welcome to IZIFIN Technology
# Enter your Name
#  ABeokuta
# Enter your years of Experience
#  22
# Enter your Age
#  43
# Your Annuanl Tax Revenue ATR  ABeokuta  is #1500000
