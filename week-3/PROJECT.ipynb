# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

def welcomeMessage(username):
    #gig employee window
    window = tk.Toplevel(root)
    window.title("Admin Box")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=f"Welcome {username}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="Welcome GIG Employee")
    label_2.pack()

    # Run the gig employee verification event Loop
    root.mainloop()

def submit():
    GIGID = username_entry.get()
    FullName = password_entry.get()

    if GIGID == "GIG001" and FullName == "Chukwuemeka Okafor":
         welcomeMessage(FullName)
    elif GIGID == "GIG002" and FullName == "Adaeze Nwosu":
        welcomeMessage(FullName)
    elif GIGID == "GIG003" and FullName == "Tunde Adeleke":
         welcomeMessage(FullName)
    elif GIGID == "GIG004" and FullName == "Ngozi Eze":
        welcomeMessage(FullName)
    elif GIGID == "GIG005" and FullName == "Emeka Chukwu":
         welcomeMessage(FullName)
    elif GIGID == "GIG006" and FullName == "Fatima Bello":
        welcomeMessage(FullName)   
    elif GIGID == "GIG007" and FullName == "Seun Adesanya":
         welcomeMessage(FullName)
    elif GIGID == "GIG008" and FullName == "Kelechi Onyekachi":
        welcomeMessage(FullName)
    elif GIGID == "GIG009" and FullName == "Hauwa Musa":
         welcomeMessage(FullName)
    elif GIGID == "GIG010" and FullName == "Rotimi Adeyemi":
        welcomeMessage(FullName)   
    elif GIGID == "GIG011" and FullName == "Chioma Obi":
         welcomeMessage(FullName)
    elif GIGID == "GIG012" and FullName == "Yusuf Garba":
        welcomeMessage(FullName)  
    elif GIGID == "GIG013" and FullName == "Blessing Okoro":
        welcomeMessage(FullName)
    elif GIGID == "GIG014" and FullName == "Taiwo Akinwale":
         welcomeMessage(FullName)
    elif GIGID == "GIG015" and FullName == "Amina Usman":
        welcomeMessage(FullName)
    elif GIGID == "GIG016" and FullName == "Ifeanyi Okonkwo":
         welcomeMessage(FullName)
    elif GIGID == "GIG017" and FullName == "Sade Fashola":
        welcomeMessage(FullName)   
    elif GIGID == "GIG018" and FullName == "Nnamdi Okeke":
         welcomeMessage(FullName)
    elif GIGID == "GIG019" and FullName == "Maryam Abdullahi":
        welcomeMessage(FullName)
    elif GIGID == "GIG020" and FullName == "Oluwaseun Balogun":
         welcomeMessage(FullName)
    elif GIGID == "GIG021" and FullName == "Chidi Nwachukwu":
        welcomeMessage(FullName)   
    elif GIGID == "GIG022" and FullName == "Aisha Lawal":
         welcomeMessage(FullName)
    elif GIGID == "GIG023" and FullName == "Gbenga Adebisi":
        welcomeMessage(FullName)     
    elif GIGID == "GIG024" and FullName == "Nneka Oduya":
        welcomeMessage(FullName)
    elif GIGID == "GIG025" and FullName == "Ibrahim Suleiman":
         welcomeMessage(FullName)
    elif GIGID == "GIG026" and FullName == "Tolulope Ogunwale":
        welcomeMessage(FullName)
    elif GIGID == "GIG027" and FullName == "Esther Aniemeka":
         welcomeMessage(FullName)
    elif GIGID == "GIG028" and FullName == "Biodun Ojo":
        welcomeMessage(FullName)   
    elif GIGID == "GIG029" and FullName == "Rukayat Folarin":
         welcomeMessage(FullName)
    elif GIGID == "GIG030" and FullName == "Chinedu Obiora":
        welcomeMessage(FullName)
    elif GIGID == "GIG031" and FullName == "Damilola Akintola":
         welcomeMessage(FullName)
    elif GIGID == "GIG032" and FullName == "Uche Okereke":
        welcomeMessage(FullName)   
    elif GIGID == "GIG033" and FullName == "Zainab Idris":
         welcomeMessage(FullName)
    elif GIGID == "GIG034" and FullName == "Femi Adeyinka":
        welcomeMessage(FullName)  
    elif GIGID == "GIG035" and FullName == "Precious Igwe":
        welcomeMessage(FullName)
    elif GIGID == "GIG036" and FullName == "Lara Oduola":
         welcomeMessage(FullName)
    elif GIGID == "GIG037" and FullName == "Tochukwu Eze":
        welcomeMessage(FullName)
    elif GIGID == "GIG038" and FullName == "Hadiza Yakubu":
         welcomeMessage(FullName)
    elif GIGID == "GIG039" and FullName == "Victor Osemeka":
        welcomeMessage(FullName)   
    elif GIGID == "GIG040" and FullName == "Chidinma Nwofor":
         welcomeMessage(FullName)
             
    else:
         messagebox.showerror("Login", "Invalid username or password")




# Create main window
root = tk. Tk()
root.title("GIG Employee Verification")
root.geometry("500x200")

# Create username label and entry
username_label = tk.Label(root, text="GIGID:")
username_label.pack()
username_entry = tk. Entry(root)
username_entry.pack()

# Create password label and entry
password_label = tk.Label(root, text="FullName:")
password_label.pack()
password_entry = tk. Entry(root)
password_entry.pack()

# Create submit button
submit_button = tk. Button(root, text="Submit", command=submit)
submit_button.pack()

# Run the main event loop
root.mainloop()
